# %% [markdown]
# # Graphs with Plotly

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
import cufflinks as cf
cf.go_online()

# %%
df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0  0.544116  0.568113  0.546932 -0.421388
# 1 -0.198221 -0.442800  0.985413 -0.166012
# 2 -0.357723  2.309188  0.134718 -0.322155
# 3  0.875035 -1.131841 -0.088068 -0.544845
# 4 -0.965943 -0.261370 -0.209594 -1.427186

# %%
df2 = pd.DataFrame({'Category': ['A','B','C'], 'Values':[32,43,50]})

# %%
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df.plot()

# %%
df.iplot(filename='df_iplot')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~marmarczak/2.embed" height="525px" width="100%"></iframe>
